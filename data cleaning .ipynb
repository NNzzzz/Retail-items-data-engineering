# %%
import pandas as pd

df = pd.read_csv("sales.csv")
print(df)
# Out:
#        SaleId  OrderId  ProductId  Quantity
# 0           1        1          3         1
# 1           2        1          7         9
# 2           3        2          5        12
# 3           4        2         10         3
# 4           5        2          4         3
# ...       ...      ...        ...       ...
# 61878   61879    11235         10         6
# 61879   61880    11235          2         1
# 61880   61881    11235          7         3
# 61881   61882    11235         12         3
# 61882   61883    11235          1         4
#
# [61883 rows x 4 columns]

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 61878    False
# 61879    False
# 61880    False
# 61881    False
# 61882    False
# Length: 61883, dtype: bool

# %%
df.isna().sum()
# Out:
# SaleId       0
# OrderId      0
# ProductId    0
# Quantity     0
# dtype: int64

# %%
print(df.shape)
# Out:
# (61883, 4)

# %%
import pandas as pd

do = pd.read_csv("orders.csv")
print(do)
# Out:
#        OrderId  CustomerId        Date
# 0            1         181  2018-01-01
# 1            2         119  2018-01-01
# 2            3          69  2018-01-01
# 3            4         173  2018-01-01
# 4            5         237  2018-01-01
# ...        ...         ...         ...
# 11230    11231          15  2020-01-10
# 11231    11232           5  2020-01-10
# 11232    11233         162  2020-01-10
# 11233    11234         164  2020-01-10
# 11234    11235         103  2020-01-10
#
# [11235 rows x 3 columns]

# %%
do.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11230    False
# 11231    False
# 11232    False
# 11233    False
# 11234    False
# Length: 11235, dtype: bool

# %%
do.isna().sum()
# Out:
# OrderId       0
# CustomerId    0
# Date          0
# dtype: int64

# %%
dc=pd.read_csv("coustmers.csv")
print(dc)
# Out:
#      CustomerId  Active             Name                           Address  \
# 0             1    True        Jason Orr          Ap #387-8229 Nullam Road
# 1             2    True     Devin Herman      P.O. Box 905, 9608 Etiam St.
# 2             3    True      Kennan Head             Ap #694-3226 Odio St.
# 3             4   False        Peter Fry           Ap #378-2594 Arcu. Road
# 4             5    True         Guy Ball               418-8277 Sociis Ave
# ..          ...     ...              ...                               ...
# 395         396    True  Gabriel Cabrera              893-8895 Lacinia St.
# 396         397    True      Upton Avila              277-2012 Aliquet Ave
# 397         398    True    Dorian Farmer            918-2741 Semper Avenue
# 398         399    True     Philip Nolan  P.O. Box 159, 4292 Turpis Street
# 399         400    True     Carter Burke                  342-2129 Nam Ave
#
# ...

# %%
dc.duplicated().sum()
# Out:
# np.int64(0)

# %%
dc.isna().sum()
# Out:
# CustomerId    0
# Active        0
# Name          0
# Address       0
# City          0
# Country       2
# Email         0
# dtype: int64

# %%
df.fillna("null")
# Out:
#        SaleId  OrderId  ProductId  Quantity
# 0           1        1          3         1
# 1           2        1          7         9
# 2           3        2          5        12
# 3           4        2         10         3
# 4           5        2          4         3
# ...       ...      ...        ...       ...
# 61878   61879    11235         10         6
# 61879   61880    11235          2         1
# 61880   61881    11235          7         3
# 61881   61882    11235         12         3
# 61882   61883    11235          1         4
#
# [61883 rows x 4 columns]

# %%
dco=pd.read_csv("countries.csv")
print(dco)
# Out:
#     Country Currency                  Name                Region  Population  \
# 0        AD      EUR               Andorra        WESTERN EUROPE       71201
# 1        AE      AED  United Arab Emirates             NEAR EAST     2602713
# 2        AF      AFN           Afghanistan  ASIA (EX. NEAR EAST)    31056997
# 3        AG      XCD     Antigua & Barbuda   LATIN AMER. & CARIB       69108
# 4        AI      XCD              Anguilla   LATIN AMER. & CARIB       13477
# ..      ...      ...                   ...                   ...         ...
# 219      YE      YER                 Yemen             NEAR EAST    21456188
# 220      YT      EUR               Mayotte    SUB-SAHARAN AFRICA      201234
# 221      ZA      ZAR          South Africa    SUB-SAHARAN AFRICA    44187637
# 222      ZM      ZMW                Zambia    SUB-SAHARAN AFRICA    11502010
# 223      ZW      ZWL              Zimbabwe    SUB-SAHARAN AFRICA    12236805
#
# ...

# %%
dco.duplicated().sum()
# Out:
# np.int64(0)

# %%
dco.isna().sum()
# Out:
# Country                                1
# Currency                               0
# Name                                   0
# Region                                 0
# Population                             0
# Area (sq. mi.)                         0
# Pop. Density (per sq. mi.)             0
# Coastline (coast per area ratio)       0
# Net migration                          3
# Infant mortality (per 1000 births)     3
# GDP ($ per capita)                     1
# Literacy (%)                          17
# Phones (per 1000)                      3
# Arable (%)                             2
# Crops (%)                              2
# Other (%)                              2
# Climate                               22
# Birthrate                              3
# Deathrate                              4
# Agriculture                           15
# Industry                              16
# Service                               15
# dtype: int64

# %%
dco.fillna("null")
# Out:
#     Country Currency                  Name                Region  Population  \
# 0        AD      EUR               Andorra        WESTERN EUROPE       71201
# 1        AE      AED  United Arab Emirates             NEAR EAST     2602713
# 2        AF      AFN           Afghanistan  ASIA (EX. NEAR EAST)    31056997
# 3        AG      XCD     Antigua & Barbuda   LATIN AMER. & CARIB       69108
# 4        AI      XCD              Anguilla   LATIN AMER. & CARIB       13477
# ..      ...      ...                   ...                   ...         ...
# 219      YE      YER                 Yemen             NEAR EAST    21456188
# 220      YT      EUR               Mayotte    SUB-SAHARAN AFRICA      201234
# 221      ZA      ZAR          South Africa    SUB-SAHARAN AFRICA    44187637
# 222      ZM      ZMW                Zambia    SUB-SAHARAN AFRICA    11502010
# 223      ZW      ZWL              Zimbabwe    SUB-SAHARAN AFRICA    12236805
#
# ...

# %%
dp=pd.read_csv("products.csv")
print(dp)
# Out:
#     ProductId      Name ManufacturedCountry  WeightGrams
# 0           1   Generac                  GB           55
# 1           2   Ambigue                  US          128
# 2           3    Vaguee                  CA          103
# 3           4   Dubioum                  PR           77
# 4           5     Fuzzi                  SG           83
# 5           6       Lax                  PK           48
# 6           7  Nebuloon                  CH          118
# 7           8  Obscurry                  AU           88
# 8           9   Uncerty                  GH           68
# 9          10  Uncleary                  PE           93
# 10         11     Tutti                  LI           81
# 11         12    Frutti                  JP          104

# %%
dp.duplicated().sum()
# Out:
# np.int64(0)

# %%
dp.isna().sum()
# Out:
# ProductId              0
# Name                   0
# ManufacturedCountry    0
# WeightGrams            0
# dtype: int64
